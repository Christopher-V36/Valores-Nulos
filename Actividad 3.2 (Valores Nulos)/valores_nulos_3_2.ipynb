# %% [markdown]
# # ACTIVIDAD 3.2

# %%
#Librerías necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Carga de archivos y eliminación de las columnas no seleccionadas

# %%
data = pd.read_csv("Tokio.csv")
data2 = data.copy()
data2 = data2.drop(columns=["id", "listing_url", "scrape_id", "source", "picture_url", "host_id", "host_url", "host_name","host_since","host_about","host_thumbnail_url","host_picture_url","host_neighbourhood","host_listings_count","host_total_listings_count","neighbourhood_group_cleansed","calendar_last_scraped","first_review","review_scores_accuracy","license","calculated_host_listings_count","calculated_host_listings_count_entire_homes","calculated_host_listings_count_private_rooms","calculated_host_listings_count_shared_rooms"])
data2
# Out:
#       last_scraped                                               name  \
# 0       2024-09-27                          Oshiage Holiday Apartment
# 1       2024-09-27                             Kero-kero house room 1
# 2       2024-09-27  4F Spacious Apartment in Shinjuku / Shibuya Tokyo
# 3       2024-09-27         5 mins Shibuya Cat modern sunny  Shimokita
# 4       2024-09-27        Stay with host Cozy private room Senju area
# ...            ...                                                ...
# 18731   2024-09-27                                          高元寺站徒步4分钟
# 18732   2024-09-27                                      和绮新快乐居（独享三间房）
# 18733   2024-09-27     G0305 位于新宿区中心位置，适合家庭和情侣；距離山手线高田马场站6分钟，交通便利，无电梯
# 18734   2024-09-27     G0202 位于新宿区中心位置，适合家庭和情侣；距離山手线高田马场站6分钟，交通便利，无电梯
# 18735   2024-09-27                           池袋エリア/駅5分/新宿－渋谷ー銀座まで簡単25
#
#                                              description  \
# 0                                                    NaN
# ...

# %%
#Convertir las columnas de tipo objeto que tenga valores numéricos a tipo numérico
#Primero se eliminan los caracteres especiales
data2['price'] = data2['price'].str.replace('$', '')
data2["host_response_rate"] = data2["host_response_rate"].str.replace('%', '')
data2["host_acceptance_rate"] = data2["host_acceptance_rate"].str.replace('%', '')
#Se convierten a tipo numérico
data2['price'] = pd.to_numeric(data2['price'], errors='coerce')
data2["host_response_rate"] = pd.to_numeric(data2["host_response_rate"], errors='coerce')
data2["host_acceptance_rate"] = pd.to_numeric(data2["host_acceptance_rate"], errors='coerce')

# %%
#Verificamos información del dataset
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18736 entries, 0 to 18735
# Data columns (total 51 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   last_scraped                 18736 non-null  object
#  1   name                         18736 non-null  object
#  2   description                  18736 non-null  object
#  3   neighborhood_overview        18736 non-null  object
#  4   host_location                18736 non-null  object
#  5   host_response_time           18736 non-null  object
#  6   host_response_rate           18123 non-null  float64
#  7   host_acceptance_rate         18296 non-null  float64
#  8   host_is_superhost            18736 non-null  object
#  9   host_verifications           18736 non-null  object
#  10  host_has_profile_pic         18736 non-null  object
#  11  host_identity_verified       18736 non-null  object
#  12  neighbourhood                18736 non-null  object
# ...

# %% [markdown]
# ## Identificar valores nullos

# %%
#Por columnas
valores_nulos = data2.isnull().sum()
valores_nulos
# Out:
# last_scraped                       0
# name                               0
# description                        0
# neighborhood_overview              0
# host_location                      0
# host_response_time                 0
# host_response_rate               613
# host_acceptance_rate             440
# host_is_superhost                  0
# host_verifications                 0
# host_has_profile_pic               0
# host_identity_verified             0
# neighbourhood                      0
# neighbourhood_cleansed             0
# latitude                           0
# longitude                          0
# property_type                      0
# room_type                          0
# accommodates                       0
# bathrooms                       1824
# bathrooms_text                     0
# bedrooms                         282
# beds                            1832
# amenities                          0
# price                          18736
# ...

# %%
#Por dataset
valores_nulos = data.isnull().sum().sum()
valores_nulos
# Out:
# np.int64(108524)

# %% [markdown]
# ## Sustitución de los valores nulos

# %%
#Sutituimos los valores nulos de las columnas de tipo object por NaN
data2["last_scraped"] = data2["last_scraped"].fillna("NaN")
data2["name"] = data2["name"].fillna("NaN")
data2["description"] = data2["description"].fillna("NaN")
data2["neighborhood_overview"] = data2["neighborhood_overview"].fillna("NaN")
data2["host_location"] = data2["host_location"].fillna("NaN")
data2["host_response_time"] = data2["host_response_time"].fillna("NaN")
data2["host_is_superhost"] = data2["host_is_superhost"].fillna("NaN")
data2["host_verifications"] = data2["host_verifications"].fillna("NaN")
data2["host_has_profile_pic"] = data2["host_has_profile_pic"].fillna("NaN")
data2["host_identity_verified"] = data2["host_identity_verified"].fillna("NaN")
data2["neighbourhood"] = data2["neighbourhood"].fillna("NaN")
data2["neighbourhood_cleansed"] = data2["neighbourhood_cleansed"].fillna("NaN")
data2["property_type"] = data2["property_type"].fillna("NaN")
data2["room_type"] = data2["room_type"].fillna("NaN")
data2["bathrooms_text"] = data2["bathrooms_text"].fillna("NaN")
data2["amenities"] = data2["amenities"].fillna("NaN")
data2["has_availability"] = data2["has_availability"].fillna("NaN")
data2["last_review"] = data2["last_review"].fillna("NaN")
data2["instant_bookable"] = data2["instant_bookable"].fillna("NaN")
#Corroboramos que no haya valores nulos
valores_nulos = data2.isnull().sum()
valores_nulos
# Out:
# last_scraped                       0
# name                               0
# description                        0
# neighborhood_overview              0
# host_location                      0
# host_response_time                 0
# host_response_rate               613
# host_acceptance_rate             440
# host_is_superhost                  0
# host_verifications                 0
# host_has_profile_pic               0
# host_identity_verified             0
# neighbourhood                      0
# neighbourhood_cleansed             0
# latitude                           0
# longitude                          0
# property_type                      0
# room_type                          0
# accommodates                       0
# bathrooms                       1824
# bathrooms_text                     0
# bedrooms                         282
# beds                            1832
# amenities                          0
# price                          18736
# ...
